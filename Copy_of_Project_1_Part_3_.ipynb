# %% [markdown]
# <a href="https://colab.research.google.com/github/majdsabha/Prediction-of-Product-Sales/blob/main/Copy_of_Project_1_Part_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project 1 - Part 3 (Core):

# %% [markdown]
# -Student Name:Majd Sabha

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fpath = '/content/drive/MyDrive/AXSOSACADEMY/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_2023.csv'

df = pd.read_csv(fpath)

# %%
#import the library.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Histograms to view the distributions of numerical features in your dataset.
plt.figure(figsize=(6,6))

plt.hist(df['Item_Outlet_Sales'],bins=20)

plt.title('Distribution of Item Outlet Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')

plt.show()

# %%
#Boxplots to view statistical summaries of numerical features in your dataset.
plt.figure(figsize=(6,4))

sns.boxplot(data=df, x='Item_MRP')

plt.title('Boxplot of Item MRP')

plt.show()

# %%
#Countplots to view the frequency of each class of categorial features in your dataset.
plt.figure(figsize=(6,4))

sns.countplot(data=df ,x='Item_Fat_Content')

plt.title('Count of Item Fat Content')

plt.show()

# %%
#Heatmap to view the correlation between features.
corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))

sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title('Correlation Heatmap')

plt.show()
